# %% [markdown]
# # Examine the temporal dynamics over the training

# %%
import meta, examine

# %% [markdown]
# # Zero pretrain

# %% [markdown]
# ## ADAM, Zero pretrain
#
# Epoch of interests:
# - 1: start
# - 10: 50% PHO, 0 SEM
# - 40: 90% PHO, 50% SEM
# - 100: Somewhat asymptotic performance
# - 300: Overtrain

# %%
cfg_json = '../../models/fast_no_pretrain/model_config.json'
cfg = meta.Config.from_json(cfg_json)
exam = examine.Examine(cfg)
# Out:
# Loaded config from ../../models/fast_no_pretrain/model_config.json

# %% [markdown]
# ### Activation == 1

# %%
sel_epochs = [1, 10, 40, 100, 300]
[exam.plot_input(task='triangle', epoch=x, act=1) for x in sel_epochs]
# Out:
# [None, None, None, None, None]

# %% [markdown]
# ### Activation == 0

# %%
sel_epochs = [1, 10, 40, 100, 300]
[exam.plot_input(task='triangle', epoch=x, act=0) for x in sel_epochs]
# Out:
# [None, None, None, None, None]

# %%
exam.mean_bias
# Out:
# {'PHO': -0.026931709, 'SEM': -0.25660768}

# %% [markdown]
# ### Summary
# - With no pretraining, the model works similar to a OP model, with the main driving force being the direct connection from orthography.
# - As the model learns, the input strength continue to increase.
# - Given the overall performance in SGD is somewhat similar to ADAM, perhaps they have similar temporal dynamics? Let's check...

# %% [markdown]
# ## SGD, Zero pretrain
#
# Epoch of interests:
# - 1: start (alreadu 60% PHO, 0 SEM)
# - 60: 90% PHO, 50% SEM
# - 200: Somewhat asymptotic performance
# - 500: Overtrain

# %%
cfg_json = '../../models/triangle_vary_pretrain_fewer/triangle_vary_pretrain_fewer_r0000/model_config.json'
cfg = meta.Config.from_json(cfg_json)
exam = examine.Examine(cfg)
# Out:
# Loaded config from ../../models/triangle_vary_pretrain_fewer/triangle_vary_pretrain_fewer_r0000/model_config.json

# %% [markdown]
# ### Activation == 1

# %%
sel_epochs = [1, 60, 200, 500]
[exam.plot_input(task='triangle', epoch=x, act=1) for x in sel_epochs]
# Out:
# [None, None, None, None]

# %% [markdown]
# ### Activation == 0

# %%
sel_epochs = [1, 60, 200, 500]
[exam.plot_input(task='triangle', epoch=x, act=0) for x in sel_epochs]
# Out:
# [None, None, None, None]

# %%
exam.mean_bias
# Out:
# {'PHO': -1.337973, 'SEM': -0.5805103}

# %% [markdown]
# ## Zero pretrain summary
# Except the slightly larger bias, SGD input temporal dynamics are similar to ADAM.
